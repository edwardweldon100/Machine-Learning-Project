# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.lines import Line2D
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.ticker as mtick
plt.style.use('ggplot')
import seaborn as sns
pd.options.display.float_format = '{:,.0f}'.format
import dataframe_image as dfi
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, KFold, cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import OneHotEncoder, StandardScaler
encoder = OneHotEncoder(sparse_output=False)
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor
from sklearn import ensemble
from sklearn.ensemble import BaggingRegressor, RandomForestRegressor
from sklearn.exceptions import ConvergenceWarning
import warnings
warnings.filterwarnings("ignore")

# %%
#Import Imputeed Ames Data
Ames = pd.read_csv('Ames_HousePrice_Imputed.csv')

#Update with new Ames Data
Ames_Columns_Numeric = Ames[[
    '1stFlrSF', '2ndFlrSF', '3SsnPorch', 'BedroomAbvGr', 'BsmtFinSF1', 'BsmtFinSF2',
    'BsmtFullBath', 'BsmtHalfBath', 'BsmtUnfSF', 'EnclosedPorch', 'Fireplaces', 'FullBath',
    'GarageArea', 'GarageCars', 'GarageYrBlt', 'GrLivArea', 'HalfBath', 'KitchenAbvGr',
    'LotArea', 'LotFrontage', 'LowQualFinSF', 'MasVnrArea', 'MiscVal', 'MoSold',
    'OpenPorchSF', 'PoolArea', 'ScreenPorch', 'TotalBsmtSF', 'TotRmsAbvGrd', 'WoodDeckSF',
    'YearBuilt', 'YearRemodAdd', 'YrSold'
]]
Ames_Columns_Ordinal = Ames[[ 
    'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'BsmtQual',
    'Electrical', 'ExterCond', 'ExterQual', 'Fence', 'FireplaceQu', 'Functional',
    'GarageCond', 'GarageFinish', 'GarageQual', 'HeatingQC', 'KitchenQual',
    'LandSlope', 'LotShape', 'OverallCond', 'OverallQual', 'PavedDrive',
    'PoolQC', 'Utilities'
]]
Ames_Columns_Nominal = Ames[[ 
    'Alley', 'BldgType', 'CentralAir', 'Condition1', 'Condition2',
    'Exterior1st', 'Exterior2nd', 'Foundation', 'GarageType', 'Heating',
    'HouseStyle', 'LandContour', 'LotConfig', 'MasVnrType', 'MiscFeature',
    'MSSubClass', 'MSZoning', 'Neighborhood', 'RoofMatl', 'RoofStyle',
    'SaleCondition', 'SaleType', 'Street'
]].astype(str)

#Combination Table of Numeric & Ordinal Columns
Ames_Columns_Numeric_Ordinal = Ames[
    list(Ames_Columns_Numeric.columns) + list(Ames_Columns_Ordinal.columns)
]
#Combination Table of Nominal & Ordinal Columns
Ames_Columns_Nominal_Ordinal = Ames[
    list(Ames_Columns_Nominal.columns) + list(Ames_Columns_Ordinal.columns)
]

# %%
encoder = OneHotEncoder(drop='first', sparse_output=False)
encoder_nominal = OneHotEncoder(drop='first', sparse_output=False)
encoder_ordinal = OneHotEncoder(drop='first', sparse_output=False)
Nominal_cols = Ames_Columns_Nominal.columns
Ordinal_cols = Ames_Columns_Ordinal.columns
Numeric_cols = Ames_Columns_Numeric.columns

# --- One-Hot Encode Nominal ---
Ames_Optimal_Nominal_One_Hot = encoder_nominal.fit_transform(Ames[Nominal_cols])
Ames_Optimal_Nominal_One_Hot_df = pd.DataFrame(
    Ames_Optimal_Nominal_One_Hot,
    columns=encoder_nominal.get_feature_names_out(Nominal_cols),
    index=Ames.index
)
#DO NOT One-Hot Encode Ordinal (for now)
Ames_Optimal_Ordinal_One_Hot = encoder_ordinal.fit_transform(Ames[Ordinal_cols])
Ames_Optimal_Ordinal_One_Hot_df = pd.DataFrame(
    Ames_Optimal_Ordinal_One_Hot,
    columns=encoder_ordinal.get_feature_names_out(Ordinal_cols),
    index=Ames.index
)
#Merge Nominal & Ordinal Encodings
Ames_Optimal_Categorical_One_Hot = pd.merge(
    Ames_Optimal_Nominal_One_Hot_df,
    Ames_Optimal_Ordinal_One_Hot_df,
    left_index=True,
    right_index=True,
    how='left'
)
#Merge with Numeric Features
Ames_MLR_Optimal_Columns = pd.merge(
    Ames[Numeric_cols],
    Ames_Optimal_Categorical_One_Hot,
    left_index=True,
    right_index=True,
    how='left'
)

# %%
Y = Ames['SalePrice']
X = Ames_MLR_Optimal_Columns

# %%
#Decision Tree Regressor 
tree_model = DecisionTreeRegressor(random_state=2)

#Grid Search
grid_para_tree = {
    'criterion': ['squared_error', 'absolute_error'],
    'max_depth': range(10, 31)
}
grid_search_tree = GridSearchCV(
    estimator=tree_model,
    param_grid=grid_para_tree,
    cv=5,
    scoring='r2',
    n_jobs=-1
)
grid_search_tree.fit(X, Y)

print('Best parameters:', grid_search_tree.best_params_)
print('Best CV accuracy: %.4f' % grid_search_tree.best_score_)
# Out:
# Best parameters: {'criterion': 'absolute_error', 'max_depth': 14}
# Best CV accuracy: 0.7457

# %%
best_tree = grid_search_tree.best_estimator_
importances = best_tree.feature_importances_

#Feature Name-Importance Pairs
feature_names = X.columns
feature_importance = list(zip(feature_names, importances))
feature_importance_sorted = sorted(feature_importance, key=lambda x: x[1], reverse=True)

#Plot Top 20 Feature Importances
top_features = feature_importance_sorted[:20]
names, values = zip(*top_features)
plt.barh(names, values)
plt.gca().invert_yaxis()
plt.xlabel('Feature Importance')
plt.title('Decision Tree Feature Importances')
plt.show()

#Print All Importances
for name, importance in feature_importance_sorted:
    print(f"{name}: {importance:.4f}")
# Out:
# YearBuilt: 0.2474
# GrLivArea: 0.1360
# GarageArea: 0.1153
# 1stFlrSF: 0.1034
# TotalBsmtSF: 0.0594
# BsmtFinSF1: 0.0219
# Fireplaces: 0.0199
# BsmtUnfSF: 0.0164
# YearRemodAdd: 0.0151
# LotArea: 0.0130
# GarageYrBlt: 0.0130
# LotFrontage: 0.0119
# 2ndFlrSF: 0.0090
# OpenPorchSF: 0.0087
# MasVnrArea: 0.0082
# OverallQual_7: 0.0079
# MoSold: 0.0073
# GarageCars: 0.0072
# WoodDeckSF: 0.0069
# OverallQual_8: 0.0069
# KitchenQual_4: 0.0063
# BsmtQual_5: 0.0063
# MSSubClass_60: 0.0050
# BsmtFullBath: 0.0049
# OverallQual_4: 0.0045
# OverallQual_3: 0.0043
# ScreenPorch: 0.0038
# BsmtExposure_1: 0.0036
# LandContour_Low: 0.0035
# OverallCond_6: 0.0032
# OverallQual_6: 0.0030
# Neighborhood_Crawfor: 0.0029
# YrSold: 0.0028
# CentralAir_Y: 0.0028
# ExterQual_2: 0.0025
# LotShape_2: 0.0021
# KitchenQual_3: 0.0020
# LotConfig_CulDSac: 0.0018
# FullBath: 0.0018
# EnclosedPorch: 0.0018
# Functional_2: 0.0018
# Neighborhood_ClearCr: 0.0018
# BsmtExposure_3: 0.0018
# ExterQual_1: 0.0017
# LotConfig_Inside: 0.0017
# HeatingQC_3: 0.0017
# GarageType_Attchd: 0.0017
# OverallCond_8: 0.0016
# FireplaceQu_3: 0.0016
# TotRmsAbvGrd: 0.0016
# MSZoning_RM: 0.0015
# GarageFinish_1: 0.0015
# BsmtQual_2: 0.0015
# LandSlope_1: 0.0014
# OverallQual_1: 0.0014
# PavedDrive_1: 0.0014
# GarageCond_3: 0.0014
# SaleType_WD : 0.0014
# BedroomAbvGr: 0.0013
# LandContour_HLS: 0.0013
# HeatingQC_4: 0.0013
# KitchenQual_2: 0.0013
# ExterCond_2: 0.0012
# OverallCond_3: 0.0012
# HouseStyle_2Story: 0.0012
# ExterCond_1: 0.0012
# SaleType_New: 0.0012
# Neighborhood_Edwards: 0.0012
# LotShape_3: 0.0011
# LandContour_Lvl: 0.0011
# Foundation_CBlock: 0.0011
# MSSubClass_160: 0.0011
# Exterior2nd_Wd Sdng: 0.0011
# RoofStyle_Gambrel: 0.0010
# MSSubClass_30: 0.0010
# HeatingQC_2: 0.0010
# SaleCondition_Normal: 0.0010
# Neighborhood_Mitchel: 0.0010
# MasVnrType_Stone: 0.0009
# Fence_3: 0.0009
# OverallCond_4: 0.0009
# PavedDrive_2: 0.0009
# Exterior1st_HdBoard: 0.0008
# Neighborhood_NridgHt: 0.0008
# GarageFinish_2: 0.0008
# BsmtCond_3: 0.0008
# GarageType_Detchd: 0.0008
# ExterCond_3: 0.0008
# OverallCond_1: 0.0008
# LowQualFinSF: 0.0008
# Exterior1st_CemntBd: 0.0008
# BsmtExposure_4: 0.0008
# Exterior2nd_Plywood: 0.0007
# Exterior1st_BrkFace: 0.0007
# Foundation_Slab: 0.0007
# BsmtFinType1_5: 0.0007
# Condition1_Norm: 0.0007
# Exterior1st_Stucco: 0.0007
# Neighborhood_Sawyer: 0.0007
# OverallCond_7: 0.0007
# OverallQual_2: 0.0007
# SaleCondition_Family: 0.0007
# Exterior1st_VinylSd: 0.0007
# Neighborhood_CollgCr: 0.0006
# BsmtCond_4: 0.0006
# OverallCond_5: 0.0006
# KitchenAbvGr: 0.0006
# BsmtFinType2_1: 0.0006
# Exterior1st_Plywood: 0.0006
# HalfBath: 0.0006
# BsmtFinType1_4: 0.0006
# BsmtFinType1_6: 0.0005
# LotConfig_FR2: 0.0005
# Exterior2nd_ImStucc: 0.0005
# 3SsnPorch: 0.0005
# PoolQC_4: 0.0005
# Foundation_PConc: 0.0005
# FireplaceQu_4: 0.0005
# Neighborhood_NAmes: 0.0005
# MasVnrType_No Veneer: 0.0005
# OverallQual_9: 0.0005
# FireplaceQu_5: 0.0005
# GarageFinish_3: 0.0005
# KitchenQual_1: 0.0005
# Condition1_PosN: 0.0005
# Condition1_RRAn: 0.0005
# GarageQual_3: 0.0004
# Exterior1st_MetalSd: 0.0004
# MSZoning_RL: 0.0004
# Neighborhood_StoneBr: 0.0004
# BsmtFinSF2: 0.0004
# BsmtFinType1_2: 0.0004
# Neighborhood_Gilbert: 0.0004
# HouseStyle_1Story: 0.0004
# OverallCond_2: 0.0004
# BsmtQual_3: 0.0004
# Exterior2nd_HdBoard: 0.0003
# SaleType_Oth: 0.0003
# GarageQual_4: 0.0003
# Neighborhood_NoRidge: 0.0003
# MiscFeature_No Misc Feature: 0.0003
# Neighborhood_SawyerW: 0.0003
# BsmtHalfBath: 0.0003
# GarageType_No Garage: 0.0003
# RoofStyle_Hip: 0.0003
# Exterior2nd_VinylSd: 0.0003
# MiscFeature_Shed: 0.0003
# RoofStyle_Gable: 0.0003
# RoofMatl_Metal: 0.0003
# Neighborhood_Blueste: 0.0002
# Electrical_2: 0.0002
# MSSubClass_50: 0.0002
# GarageCond_2: 0.0002
# Exterior2nd_MetalSd: 0.0002
# Heating_GasA: 0.0002
# Functional_1: 0.0002
# Exterior1st_Wd Sdng: 0.0002
# BsmtQual_4: 0.0002
# MSSubClass_120: 0.0002
# FireplaceQu_2: 0.0002
# Fence_4: 0.0002
# OverallQual_5: 0.0002
# MasVnrType_BrkFace: 0.0002
# MSSubClass_90: 0.0002
# Utilities_1: 0.0001
# Exterior1st_WdShing: 0.0001
# Neighborhood_SWISU: 0.0001
# LotConfig_FR3: 0.0001
# Neighborhood_BrkSide: 0.0001
# BldgType_Twnhs: 0.0001
# Exterior2nd_BrkFace: 0.0001
# MSSubClass_190: 0.0001
# BsmtCond_2: 0.0001
# BsmtFinType1_1: 0.0001
# Alley_No Alley Access: 0.0001
# BldgType_2fmCon: 0.0001
# Exterior2nd_Stucco: 0.0001
# BldgType_TwnhsE: 0.0001
# Condition1_Feedr: 0.0001
# Neighborhood_IDOTRR: 0.0001
# BsmtFinType2_3: 0.0001
# MSSubClass_80: 0.0001
# MSZoning_RH: 0.0001
# MiscVal: 0.0001
# GarageType_BuiltIn: 0.0001
# HouseStyle_SFoyer: 0.0001
# HouseStyle_SLvl: 0.0001
# BsmtFinType1_3: 0.0001
# FireplaceQu_1: 0.0000
# Exterior2nd_CmentBd: 0.0000
# GarageQual_2: 0.0000
# HouseStyle_2.5Unf: 0.0000
# Functional_4: 0.0000
# MSZoning_FV: 0.0000
# Neighborhood_Somerst: 0.0000
# MSSubClass_70: 0.0000
# BldgType_Duplex: 0.0000
# Electrical_3: 0.0000
# Functional_6: 0.0000
# Condition2_PosA: 0.0000
# Condition1_RRAe: 0.0000
# SaleCondition_Partial: 0.0000
# PoolArea: 0.0000
# Alley_Pave: 0.0000
# Condition1_PosA: 0.0000
# Condition1_RRNe: 0.0000
# Condition1_RRNn: 0.0000
# Condition2_Feedr: 0.0000
# Condition2_Norm: 0.0000
# Condition2_PosN: 0.0000
# Condition2_RRAe: 0.0000
# Condition2_RRAn: 0.0000
# Condition2_RRNn: 0.0000
# Exterior1st_AsphShn: 0.0000
# Exterior1st_BrkComm: 0.0000
# Exterior1st_CBlock: 0.0000
# Exterior1st_ImStucc: 0.0000
# Exterior1st_PreCast: 0.0000
# Exterior2nd_AsphShn: 0.0000
# Exterior2nd_Brk Cmn: 0.0000
# Exterior2nd_CBlock: 0.0000
# Exterior2nd_PreCast: 0.0000
# Exterior2nd_Stone: 0.0000
# Exterior2nd_Wd Shng: 0.0000
# Foundation_Stone: 0.0000
# Foundation_Wood: 0.0000
# GarageType_Basment: 0.0000
# GarageType_CarPort: 0.0000
# Heating_GasW: 0.0000
# Heating_Grav: 0.0000
# Heating_OthW: 0.0000
# Heating_Wall: 0.0000
# HouseStyle_1.5Unf: 0.0000
# HouseStyle_2.5Fin: 0.0000
# MiscFeature_Othr: 0.0000
# MiscFeature_TenC: 0.0000
# MSSubClass_40: 0.0000
# MSSubClass_45: 0.0000
# MSSubClass_75: 0.0000
# MSSubClass_85: 0.0000
# MSSubClass_150: 0.0000
# MSSubClass_180: 0.0000
# MSZoning_C (all): 0.0000
# MSZoning_I (all): 0.0000
# Neighborhood_BrDale: 0.0000
# Neighborhood_Greens: 0.0000
# Neighborhood_GrnHill: 0.0000
# Neighborhood_Landmrk: 0.0000
# Neighborhood_MeadowV: 0.0000
# Neighborhood_NPkVill: 0.0000
# Neighborhood_NWAmes: 0.0000
# Neighborhood_OldTown: 0.0000
# Neighborhood_Timber: 0.0000
# Neighborhood_Veenker: 0.0000
# RoofMatl_Membran: 0.0000
# RoofMatl_Roll: 0.0000
# RoofMatl_Tar&Grv: 0.0000
# RoofMatl_WdShake: 0.0000
# RoofMatl_WdShngl: 0.0000
# RoofStyle_Mansard: 0.0000
# RoofStyle_Shed: 0.0000
# SaleCondition_AdjLand: 0.0000
# SaleCondition_Alloca: 0.0000
# SaleType_CWD: 0.0000
# SaleType_Con: 0.0000
# SaleType_ConLD: 0.0000
# SaleType_ConLI: 0.0000
# SaleType_ConLw: 0.0000
# SaleType_VWD: 0.0000
# Street_Pave: 0.0000
# BsmtCond_1: 0.0000
# BsmtCond_5: 0.0000
# BsmtExposure_2: 0.0000
# BsmtFinType2_2: 0.0000
# BsmtFinType2_4: 0.0000
# BsmtFinType2_5: 0.0000
# BsmtFinType2_6: 0.0000
# BsmtQual_1: 0.0000
# Electrical_1: 0.0000
# ExterCond_4: 0.0000
# ExterQual_3: 0.0000
# Fence_1: 0.0000
# Fence_2: 0.0000
# Functional_3: 0.0000
# Functional_5: 0.0000
# GarageCond_1: 0.0000
# GarageCond_4: 0.0000
# GarageCond_5: 0.0000
# GarageQual_1: 0.0000
# GarageQual_5: 0.0000
# HeatingQC_1: 0.0000
# LandSlope_2: 0.0000
# LotShape_1: 0.0000
# PoolQC_1: 0.0000
# PoolQC_2: 0.0000
# PoolQC_3: 0.0000

# %%
base_tree = DecisionTreeRegressor(random_state=2)
bagging_model = BaggingRegressor()

bag = cross_val_score(BaggingRegressor(random_state=2), X, Y, cv=5, scoring='r2')
bag.mean()
# Out:
# np.float64(0.8629139839648203)

# %%
#Initial Bagging RandomizedSearchCV for faster estimates
param_dist = {
    'estimator__criterion': ['squared_error', 'absolute_error'],
    'estimator__max_depth': [14, 15, 16],
    'n_estimators': [88, 89, 90]
}
random_search = RandomizedSearchCV(
    bagging_model,
    param_distributions=param_dist,
    n_iter=20,
    cv=5,
    scoring='r2',
    n_jobs=-1,
    random_state=2,
    verbose=1
)
random_search.fit(X, Y)
print('Best parameters:', random_search.best_params_)
print(f'Best CV Score: {random_search.best_score_:.4f}')
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# Best parameters: {'n_estimators': 89, 'estimator__max_depth': 15, 'estimator__criterion': 'squared_error'}
# Best CV Score: 0.8912

# %%
#Final Bagging Grid Search
grid_params_bagging = {
    'estimator__criterion': ['squared_error', 'friedman_mse', 'absolute_error'],
    'estimator__max_depth': [13, 17],
    'n_estimators': [85, 95]
}
grid_search_bagging = GridSearchCV(
    estimator=bagging_model,
    param_grid=grid_params_bagging,
    cv=5,
    scoring='r2',
    n_jobs=-1,
    verbose=1
)
grid_search_bagging.fit(X, Y)

print('Best parameters:', grid_search_bagging.best_params_)
print(f'Best CV R²: {grid_search_bagging.best_score_:.4f}')
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Best parameters: {'estimator__criterion': 'friedman_mse', 'estimator__max_depth': 17, 'n_estimators': 85}
# Best CV R²: 0.8893

# %%
#Bagging Feature Importances (bagging averages)
best_bagging = grid_search_bagging.best_estimator_
importances = np.mean(
    [tree.feature_importances_ for tree in best_bagging.estimators_],
    axis=0
)
#Pair with Feature Names
feature_importance = list(zip(X.columns, importances))
feature_importance_sorted = sorted(feature_importance, key=lambda x: x[1], reverse=True)

#Plot Top 20 Feature Importances
top_features = feature_importance_sorted[:20]
names, values = zip(*top_features)
plt.barh(names, values)
plt.gca().invert_yaxis()
plt.xlabel('Feature Importance')
plt.title('Bagging Regressor Feature Importances')
plt.show()

#Print all Importances
for name, importance in feature_importance_sorted:
    print(f"{name}: {importance:.4f}")
